

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver import ActionChains
import time
from bs4 import BeautifulSoup
driver = webdriver.Chrome('C:/Users/SSAFY/Desktop/selenium/chromedriver.exe')
url = 'https://map.naver.com/v5/search'
driver.get(url)

# %%
import pandas as pd

# %%
columns = ['title','subway','theme_keyword','review','rank']
df_places = pd.DataFrame(columns=columns)

# %%
places = ['부산 흰여울문화마을', '부산 깡깡이 예술마을', '부산 국립해양박물관', '부산 태종대 유원지', '부산 죽성성당', '부산 아홉산 숲', '부산 해동용궁사', '부산 임랑해수욕장 ', '부산 문화공감 수정', '부산 일광해수욕장', '부산 구 백제병원', '부산 백산기념관', '부산 한성1918 부산생활문화센터', '부산 조선통신사역사관', '부산 부산해양자연사박물관', '부산 부산근대역사관', '부산 보수동책방골목', '부산 임시수도기념관', '부산 동아대학교 석당박물관', '부산 국립일제강제동원역사관', '부산 부산박물관', '부산 유엔기념공원', '부산 오륙도', '부산 신선대', '부산 송정해수욕장', '죽도공원', '부산 아난티코브 타운, 이터널저니', '부산 스카이워크 시리즈', '부산 민락수변공원', '부산 송도해수욕장', '부산 아미산전망대', '부산 아미동 비석마을', '부산 부산시립미술관', '부산 오랑대공원', '부산 국립수산과학관', '부산 요산문학관', '부산 박차정의사 생가', '부산 우장춘 기념관', '부산 누리바라기전망대', '부산 최민식갤러리', '부산 수영사적공원', '부산 부산기상관측소', '부산 을숙도', '부산 부산시청자미디어센터', '부산 구포어린이교통공원', '부산 부산솔로몬로파크', '부산 부산어촌민속관', '부산 삼락생태공원', '부산 암남공원/송도해안볼레길', '부산 장림포구 ', '부산 가덕도', '부산 렛츠런파크 부산경남', '부산 국립부산과학관', '부산 송상현광장', '부산 부산어린이대공원', '부산 국립부산립국악원', '부산 삼광사', '부산 청사포와 미포', '부산 뮤지엄다', '부산 부산시민공원', '부산 호천마을', '부산 봉래산', '부산 영화의 거리', '부산 APEC나루공원', '부산 40계단', '부산 감천문화마을', '부산 다대포 해수욕장', '부산 부산영화체험박물관, 트릭아이뮤지엄부산', '부산 용두산공원', '부산 영도대교', '부산 중앙공원, 민주공원', '부산 황령산 전망쉼터', '부산 F1963', '부산 해운대', '부산 광안리 해수욕장', '부산 금정산', '부산 금강공원/식물원', '부산 범어사', '부산 동래읍성', '부산 상해거리', '부산 이중섭문화거리', '부산 복천박물관, 복천동고분군', '부산 벡스코', '부산 영화의 전당', '부산 장안사', '부산 백양산', '부산 성지곡수원지', '부산 장산', '부산 석불사', '부산 회동수원지', '부산 동래향교, 기장향교', '부산 가덕도 연대봉', '부산 승학산 억새평원', '부산 대룡마을', '부산 대신공원', '부산 화명수목원', '부산 선암사', '부산 운수사', '부산 스포원파크', '부산 우암동 소막마을', '부산 충렬사', '부산 부산커피박물관', '부산 사상생활사박물관', '부산 사직야구장', '부산 기장 도예 관광 힐링촌 테마숲', '부산 송도용궁구름다리', '부산 우암동 소막마을', '부산 부산치유의 숲', '부산 아미동비석마을', '부산 유엔기념공원, 유엔평화기념관', '부산 기장 달음산 자연휴양림', '부산 부산도서관', '부산 해운대 수목원', '부산 캐비네 드 쁘아송', '부산 영도 봉산마을', '부산 KT&G상상마당 부산']
# places = ['부산 흰여울문화마을']
# 여행지 검색
search_box = driver.find_element_by_css_selector('div.input_box>input.input_search')

for place in places :
    search_box.send_keys(place)
    time.sleep(1)
    search_box.send_keys(Keys.ENTER)
    time.sleep(2)
    
    searchiframe = driver.find_element_by_id("searchIframe")
    driver.switch_to.frame(searchiframe)
    
    html = driver.page_source # 이거 계속있어야하는 건지 검색해보기
    soup = BeautifulSoup(html, 'html.parser') 
    try :
        try :
            place_ul = soup.select_one('div._1Az1K > ul')
            place_li = place_ul.select('li')
            # 가장 첫번째 것만 클릭해서 정보 가져오기
            #_pcmap_list_scroll_container > ul > li:nth-child(1) > div._3ZU00 > a:nth-child(1)
            driver.find_element_by_css_selector('#_pcmap_list_scroll_container > ul > li:nth-child(1) > div._3ZU00 > a:nth-child(1)').click()
            time.sleep(2)
        except :
            pass
        driver.switch_to.default_content()

        entryIframe = driver.find_element_by_id("entryIframe")
        driver.switch_to.frame(entryIframe)
        
        html = driver.page_source # 클릭 후 페이지가져오기
        soup = BeautifulSoup(html, 'html.parser')
        place_detail_wrapper = soup.select_one('div.place_detail_wrapper')
        try :
            title = place_detail_wrapper.select('span._3XamX')[0].text
            print(title)
        except :
            title = ''
        
            
        # 지하철
        try :
            subway_tag = place_detail_wrapper.select('div._2P6sT')[0]
            subway_tag.find('span').decompose() # span태그 빼기
            subway = subway_tag.text
#             print(subway)
        except :
            subway =''
        
        # 테마키워드
        try :
            theme_kw_ul =  place_detail_wrapper.select('ul._2CguG')
            theme_kw_li = theme_kw_ul[0].select('li')
            theme_keyword = []
            for i in range(len(theme_kw_li)):
                theme_kw_span = theme_kw_li[i].select('span')
                for j in range(1,len(theme_kw_span)) :
                    theme_keyword.append(theme_kw_span[j].text)
#             print(theme_keyword)
        except :
            theme_keyword = ''
        
        # 리뷰
        find_review_table = soup.select_one('div._2MDmw')
        # print(driver.find_element_by_css_selector('div.place_detail_wrapper > div.place_fixed_maintab > div > div > div > div > a:nth-child(1) > span')
        for i in range(len(find_review_table)) :
            path = 'div.place_detail_wrapper > div.place_fixed_maintab > div > div > div > div > a:nth-child({0}) > span'.format(i+1)
            if driver.find_element_by_css_selector(path).text == '리뷰':
                driver.find_element_by_css_selector(path).click()
                break

        flag = 1
        click_n = 0
        time.sleep(2)
        while flag :
            if click_n >= 10 :
                break
            try :
                driver.find_element_by_css_selector('div._2kAri').click()
                time.sleep(0.5)
                click_n += 1
            except :
                flag = 0
        html = driver.page_source # 내리고 나서의 페이지를 싹 가져옴
        soup = BeautifulSoup(html, 'html.parser') 
        reviews_ul = soup.select_one('ul._1jVSG')
        reviews_li = reviews_ul.select('li')

        for i in range(len(reviews_li)):
#             print(len(reviews_li))
            try :
                review = reviews_li[i].select('span.WoYOw')[0].text
#                 print(review)
            except :
                review = ''
            try :
                rank = reviews_li[i].select('span.Sv1wj')[0].text[2:]
#                 print(rank)
            except :
                rank = ''
#                 print(rank)
            df_places = df_places.append({
                'title':title,
                'subway':subway,
                'theme_keyword':theme_keyword,
                'review':review,
                'rank':rank
            },ignore_index=True)
            
    except :
        pass

    driver.switch_to.default_content()
    search_box.clear() # 검색어 비우기
    time.sleep(0.5)
    print(len(df_places))
# Out:
# 흰여울문화마을
# 13
# 깡깡이예술마을
# 13
# 국립해양박물관
# 54
# 태종대
# 164
# 죽성드림세트장
# 165
# 아홉산숲
# 275
# 해동용궁사
# 275
# 임랑해수욕장
# 279
# 문화공감수정
# 292
# 일광해수욕장
# 292
# 산천
# 292
# 백산기념관
# 293
# 한성1918 부산생활문화센터
# 295
# 조선통신사역사관
# 295
# 부산해양자연사박물관
# 301
# 부산근대역사관
# 302
# 보수동책방골목
# 302
# 임시수도기념관
# 304
# 동아대학교 석당박물관
# 319
# 국립일제강제동원역사관
# 338
# 부산박물관
# 341
# 유엔기념공원
# 341
# 오륙도
# 345
# 부산항신선대컨테이너터미널
# 346
# 부산 송정해수욕장
# 352
# 죽도공원
# 358
# 이터널 저니
# 468
# 468
# 민락수변공원
# 480
# 부산송도해수욕장
# 527
# 아미산전망대
# 529
# 비석문화마을
# 530
# 부산시립미술관
# 585
# 585
# 국립수산과학원수산과학관
# 585
# 요산문학관
# 585
# 박차정의사생가
# 586
# 우장춘기념관
# 586
# 누리바라기
# 587
# 최민식갤러리
# 587
# 수영사적공원
# 589
# 부산기상관측소
# 589
# 을숙도
# 600
# 부산시청자미디어센터
# 601
# 구포어린이교통공원
# 602
# 솔로몬로파크
# 604
# 부산어촌민속관
# 610
# 삼락생태공원
# 627
# 627
# 장림포구
# 627
# 가덕도
# 633
# 렛츠런파크 부산경남
# 637
# 국립부산과학관
# 747
# 송상현광장
# 747
# 부산어린이대공원
# 760
# 760
# 삼광사
# 760
# 760
# 뮤지엄 원
# 870
# 부산시민공원
# 980
# 호천문화플랫폼
# 986
# 봉래산
# 986
# 부산영화의거리
# 986
# APEC나루공원
# 1050
# 40계단거리
# 1050
# 감천문화마을
# 1147
# 다대포해수욕장
# 1187
# ...

# %%
df_places= df_places.drop(labels=range(0,13))

# %%
print(df_places)
# Out:
# Empty DataFrame
# Columns: [title, subway, theme_keyword, review, rank]
# Index: []

# %%
df_places.to_csv(path_or_buf='places_df.csv',encoding='utf-8-sig')
